# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Data.csv')
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
print(x)
# Out:
# [[1 'France' 44.0 72000.0]
#  [2 'Spain' 27.0 48000.0]
#  [3 'Germany' 30.0 54000.0]
#  [4 'Spain' 38.0 61000.0]
#  [5 'Germany' 40.0 nan]
#  [6 'France' 35.0 58000.0]
#  [7 'Spain' nan 52000.0]
#  [8 'France' 48.0 79000.0]
#  [9 'Germany' 50.0 83000.0]
#  [10 'France' 37.0 67000.0]]

# %%
print(y)
# Out:
# ['No' 'Yes' 'No' 'No' 'Yes' 'Yes' 'No' 'Yes' 'No' 'Yes']

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(x[:, 1:3])
x[:, 1:3] = imputer.transform(x[:, 1:3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-29649d3f3f64> in <module>()
#       1 from sklearn.impute import SimpleImputer
#       2 imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
# ----> 3 imputer.fit(x[:, 1:3])
#       4 x[:, 1:3] = imputer.transform(x[:, 1:3])
#
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_base.py in fit(self, X, y)
#     266         self : SimpleImputer
#     267         """
# --> 268         X = self._validate_input(X)
#     269         super()._fit_indicator(X)
#     270
#
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_base.py in _validate_input(self, X)
#     238                 new_ve = ValueError("Cannot use {} strategy with non-numeric "
#     239                                     "data:\n{}".format(self.strategy, ve))
# --> 240                 raise new_ve from None
#     241             else:
#     242                 raise ve
#
# ValueError: Cannot use mean strategy with non-numeric data:
# could not convert string to float: 'France'

# %%
print(x)
# Out:
# [['France;44;72000;No']
#  ['Spain;27;48000;Yes']
#  ['Germany;30;54000;No']
#  ['Spain;38;61000;No']
#  ['Germany;40;;Yes']
#  ['France;35;58000;Yes']
#  ['Spain;;52000;No']
#  ['France;48;79000;Yes']
#  ['Germany;50;83000;No']
#  ['France;37;67000;Yes']]

# %%
print(y)
# Out:
# ['Spain;27;48000;Yes' 'Germany;30;54000;No' 'Spain;38;61000;No'
#  'Germany;40;;Yes' 'France;35;58000;Yes' 'Spain;;52000;No'
#  'France;48;79000;Yes' 'Germany;50;83000;No' 'France;37;67000;Yes']
